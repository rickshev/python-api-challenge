# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# empty lists to fill with api weather info
cities_found = []
clouds = []
countries = []
dates = []
humid = []
latit = []
lngit = []
temps = []
wind = []

# count records and sets
count = 1
group_set = 1


print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# for loop to list append each city's data
for city in cities:  
    # try and except missing data
    try: 
        response_json = requests.get(f"{url}&q={city}").json() 
        clouds.append(response_json["clouds"]["all"])
        countries.append(response_json["sys"]["country"])
        dates.append(response_json["dt"])
        humid.append(response_json["main"]["humidity"])
        temps.append(response_json["main"]["temp_max"])
        latit.append(response_json["coord"]["lat"])
        lngit.append(response_json["coord"]["lon"])
        wind.append(response_json["wind"]["speed"])
        city_index = response_json["name"]
        if count >= 50:
            count = 1
            group_set += 1
            cities_found.append(response_json["name"])
        else:
            cities_found.append(response_json["name"])
            count += 1
        
        print(f"Processing Record {count} of Set {group_set} | {city}")
        
        #  pause loop for second to not exceed API usage
        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
        
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | altos del rosario
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | princeton
# Processing Record 11 of Set 1 | tigzirt
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | saldanha
# Processing Record 18 of Set 1 | dunedin
# Processing Record 19 of Set 1 | cadillac
# City not found. Skipping...
# Processing Record 20 of Set 1 | dzhebariki-khaya
# Processing Record 21 of Set 1 | itoman
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | broome
# City not found. Skipping...
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | pemberton
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | kang
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | vila do maio
# Processing Record 35 of Set 1 | ninh binh
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | kilindoni
# Processing Record 38 of Set 1 | kavaratti
# Processing Record 39 of Set 1 | gombong
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 43 of Set 1 | hohhot
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | amos
# Processing Record 47 of Set 1 | belmonte
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | grindavik
# City not found. Skipping...
# Processing Record 50 of Set 1 | sandwick
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | xiaoyi
# Processing Record 4 of Set 2 | yaan
# Processing Record 5 of Set 2 | jardim
# Processing Record 6 of Set 2 | mitsamiouli
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | hamilton
# Processing Record 11 of Set 2 | fort nelson
# Processing Record 12 of Set 2 | svetlogorsk
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | port hardy
# Processing Record 15 of Set 2 | esperance
# City not found. Skipping...
# Processing Record 16 of Set 2 | illela
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | ngunguru
# Processing Record 19 of Set 2 | ancud
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 2 | nueva loja
# Processing Record 21 of Set 2 | prince george
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | teya
# Processing Record 24 of Set 2 | saint anthony
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | pak phanang
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | huangchuan
# Processing Record 31 of Set 2 | pevek
# Processing Record 32 of Set 2 | ignacio de la llave
# Processing Record 33 of Set 2 | bay roberts
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | preobrazheniye
# Processing Record 36 of Set 2 | te anau
# Processing Record 37 of Set 2 | palmer
# Processing Record 38 of Set 2 | ligayan
# Processing Record 39 of Set 2 | muros
# Processing Record 40 of Set 2 | rincon
# Processing Record 41 of Set 2 | zhigansk
# City not found. Skipping...
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | pierre
# Processing Record 44 of Set 2 | verkhniy baskunchak
# Processing Record 45 of Set 2 | bilma
# Processing Record 46 of Set 2 | walvis bay
# Processing Record 47 of Set 2 | trinidad
# Processing Record 48 of Set 2 | neftcala
# City not found. Skipping...
# Processing Record 49 of Set 2 | padang
# City not found. Skipping...
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | korla
# Processing Record 3 of Set 3 | mount gambier
# Processing Record 4 of Set 3 | caravelas
# Processing Record 5 of Set 3 | mont-dore
# Processing Record 6 of Set 3 | dukat
# Processing Record 7 of Set 3 | tuburan
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | biloli
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | maragogipe
# Processing Record 14 of Set 3 | puerto ayora
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | nzega
# Processing Record 17 of Set 3 | krivodol
# Processing Record 18 of Set 3 | aitape
# Processing Record 19 of Set 3 | amudat
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | senneterre
# Processing Record 22 of Set 3 | mangai
# Processing Record 23 of Set 3 | samarai
# Processing Record 24 of Set 3 | sobolevo
# Processing Record 25 of Set 3 | naze
# Processing Record 26 of Set 3 | evensk
# Processing Record 27 of Set 3 | kifri
# Processing Record 28 of Set 3 | tabat
# Processing Record 29 of Set 3 | nanortalik
# Processing Record 30 of Set 3 | san cristobal
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | oros
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | gizo
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | abu samrah
# Processing Record 41 of Set 3 | kandrian
# Processing Record 42 of Set 3 | portland
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | beyneu
# Processing Record 45 of Set 3 | weligama
# Processing Record 46 of Set 3 | puerto madryn
# Processing Record 47 of Set 3 | fonte boa
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 50 of Set 3 | lohardaga
# City not found. Skipping...
# Processing Record 1 of Set 4 | ilhabela
# Processing Record 2 of Set 4 | lavrentiya
# Processing Record 3 of Set 4 | qaqortoq
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | quzhou
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | dalen
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | cascais
# Processing Record 10 of Set 4 | tulun
# City not found. Skipping...
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | mosquera
# Processing Record 13 of Set 4 | blythe
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | mana
# City not found. Skipping...
# Processing Record 16 of Set 4 | victor harbor
# Processing Record 17 of Set 4 | namibe
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | san ramon
# Processing Record 20 of Set 4 | manggar
# Processing Record 21 of Set 4 | warman
# Processing Record 22 of Set 4 | marsala
# Processing Record 23 of Set 4 | hurricane
# Processing Record 24 of Set 4 | zeya
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | bakel
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | deputatskiy
# Processing Record 29 of Set 4 | leningradskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | diamantina
# Processing Record 31 of Set 4 | jumla
# Processing Record 32 of Set 4 | kenora
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | flin flon
# Processing Record 35 of Set 4 | suez
# City not found. Skipping...
# Processing Record 36 of Set 4 | sassandra
# Processing Record 37 of Set 4 | quatre cocos
# Processing Record 38 of Set 4 | hermanus
# Processing Record 39 of Set 4 | pangkalanbuun
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | port macquarie
# Processing Record 42 of Set 4 | shingu
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | biskamzha
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | tautira
# Processing Record 47 of Set 4 | maragogi
# Processing Record 48 of Set 4 | krasnoselkup
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 4 | katsuura
# Processing Record 50 of Set 4 | margate
# Processing Record 1 of Set 5 | asau
# Processing Record 2 of Set 5 | sulangan
# Processing Record 3 of Set 5 | izhmorskiy
# Processing Record 4 of Set 5 | maltahohe
# Processing Record 5 of Set 5 | delesti
# Processing Record 6 of Set 5 | gobabis
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | lensk
# Processing Record 9 of Set 5 | kuvandyk
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | kuusamo
# Processing Record 12 of Set 5 | ossora
# Processing Record 13 of Set 5 | hirara
# Processing Record 14 of Set 5 | bud
# Processing Record 15 of Set 5 | kenai
# Processing Record 16 of Set 5 | kimbe
# Processing Record 17 of Set 5 | honda
# Processing Record 18 of Set 5 | viedma
# Processing Record 19 of Set 5 | baykit
# City not found. Skipping...
# Processing Record 20 of Set 5 | lamu
# Processing Record 21 of Set 5 | chara
# Processing Record 22 of Set 5 | rocha
# Processing Record 23 of Set 5 | kabompo
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | sioux lookout
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | konevo
# Processing Record 29 of Set 5 | kaitangata
# City not found. Skipping...
# Processing Record 30 of Set 5 | aswan
# Processing Record 31 of Set 5 | seymchan
# Processing Record 32 of Set 5 | seddon
# City not found. Skipping...
# Processing Record 33 of Set 5 | pontianak
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | ratnagiri
# Processing Record 36 of Set 5 | laguna
# City not found. Skipping...
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | pemangkat
# Processing Record 40 of Set 5 | talara
# Processing Record 41 of Set 5 | nerja
# Processing Record 42 of Set 5 | pitimbu
# Processing Record 43 of Set 5 | bonavista
# Processing Record 44 of Set 5 | batagay-alyta
# Processing Record 45 of Set 5 | healesville
# Processing Record 46 of Set 5 | haines junction
# Processing Record 47 of Set 5 | yamada
# Processing Record 48 of Set 5 | taldan
# Processing Record 49 of Set 5 | garowe
# Processing Record 50 of Set 5 | port augusta
# Processing Record 1 of Set 6 | sibolga
# Processing Record 2 of Set 6 | pisco
# Processing Record 3 of Set 6 | marsh harbour
# Processing Record 4 of Set 6 | bugarama
# Processing Record 5 of Set 6 | nortelandia
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | hermitage
# Processing Record 8 of Set 6 | nuuk
# Processing Record 9 of Set 6 | mitu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 6 | grand forks
# Processing Record 11 of Set 6 | lakes entrance
# Processing Record 12 of Set 6 | udachnyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | midland
# Processing Record 14 of Set 6 | chegdomyn
# Processing Record 15 of Set 6 | sao filipe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 6 | soe
# Processing Record 17 of Set 6 | college place
# Processing Record 18 of Set 6 | turukhansk
# Processing Record 19 of Set 6 | marathon
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | jalu
# Processing Record 22 of Set 6 | broken hill
# City not found. Skipping...
# Processing Record 23 of Set 6 | whitley bay
# Processing Record 24 of Set 6 | salina cruz
# Processing Record 25 of Set 6 | denpasar
# Processing Record 26 of Set 6 | marquette
# Processing Record 27 of Set 6 | kuytun
# City not found. Skipping...
# Processing Record 28 of Set 6 | skhisma
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | butembo
# Processing Record 31 of Set 6 | fowa
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | high prairie
# Processing Record 34 of Set 6 | atherton
# Processing Record 35 of Set 6 | nisia floresta
# Processing Record 36 of Set 6 | husavik
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | lac du bonnet
# City not found. Skipping...
# Processing Record 39 of Set 6 | auki
# Processing Record 40 of Set 6 | marawi
# Processing Record 41 of Set 6 | norman wells
# Processing Record 42 of Set 6 | tateyama
# City not found. Skipping...
# Processing Record 43 of Set 6 | comodoro rivadavia
# Processing Record 44 of Set 6 | tigil
# Processing Record 45 of Set 6 | albolote
# City not found. Skipping...
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | tura
# Processing Record 48 of Set 6 | pingliang
# Processing Record 49 of Set 6 | le vauclin
# Processing Record 50 of Set 6 | kingsville
# Processing Record 1 of Set 7 | gladstone
# Processing Record 2 of Set 7 | pitsunda
# Processing Record 3 of Set 7 | cap-aux-meules
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | acapulco
# Processing Record 6 of Set 7 | yerbogachen
# Processing Record 7 of Set 7 | koungou
# Processing Record 8 of Set 7 | naryan-mar
# Processing Record 9 of Set 7 | tayu
# City not found. Skipping...
# Processing Record 10 of Set 7 | iwanai
# Processing Record 11 of Set 7 | santiago del estero
# Processing Record 12 of Set 7 | moose factory
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | bereznik
# Processing Record 15 of Set 7 | vicuna
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | beboto
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | aleppo
# Processing Record 20 of Set 7 | sembe
# Processing Record 21 of Set 7 | hammerfest
# Processing Record 22 of Set 7 | harper
# Processing Record 23 of Set 7 | tazovskiy
# Processing Record 24 of Set 7 | prince rupert
# City not found. Skipping...
# Processing Record 25 of Set 7 | bengkulu
# Processing Record 26 of Set 7 | sao miguel do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 7 | maceio
# Processing Record 28 of Set 7 | champerico
# Processing Record 29 of Set 7 | sechura
# Processing Record 30 of Set 7 | bereda
# Processing Record 31 of Set 7 | alugan
# City not found. Skipping...
# Processing Record 32 of Set 7 | vigrestad
# Processing Record 33 of Set 7 | coihaique
# Processing Record 34 of Set 7 | tasca
# Processing Record 35 of Set 7 | kaoma
# Processing Record 36 of Set 7 | valparaiso
# Processing Record 37 of Set 7 | buala
# Processing Record 38 of Set 7 | atar
# Processing Record 39 of Set 7 | jeremie
# Processing Record 40 of Set 7 | krasnyye baki
# Processing Record 41 of Set 7 | san jose de las lajas
# Processing Record 42 of Set 7 | tecoanapa
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | dumai
# Processing Record 45 of Set 7 | kuliyapitiya
# Processing Record 46 of Set 7 | lingdong
# Processing Record 47 of Set 7 | spirit river
# Processing Record 48 of Set 7 | murgab
# Processing Record 49 of Set 7 | mount isa
# Processing Record 50 of Set 7 | nioro
# City not found. Skipping...
# Processing Record 1 of Set 8 | dwarka
# Processing Record 2 of Set 8 | nabire
# Processing Record 3 of Set 8 | thompson
# Processing Record 4 of Set 8 | talpa
# Processing Record 5 of Set 8 | san policarpo
# Processing Record 6 of Set 8 | labuhan
# Processing Record 7 of Set 8 | mortka
# Processing Record 8 of Set 8 | kabalo
# Processing Record 9 of Set 8 | havre-saint-pierre
# Processing Record 10 of Set 8 | yichun
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | port-gentil
# City not found. Skipping...
# Processing Record 13 of Set 8 | westport
# Processing Record 14 of Set 8 | ferrenafe
# Processing Record 15 of Set 8 | puerto del rosario
# City not found. Skipping...
# Processing Record 16 of Set 8 | sorkjosen
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | sisimiut
# City not found. Skipping...
# Processing Record 19 of Set 8 | pacifica
# Processing Record 20 of Set 8 | xichang
# Processing Record 21 of Set 8 | kindersley
# Processing Record 22 of Set 8 | mahebourg
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | kos
# City not found. Skipping...
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | horodnytsya
# Processing Record 27 of Set 8 | grand gaube
# Processing Record 28 of Set 8 | hithadhoo
# Processing Record 29 of Set 8 | molteno
# Processing Record 30 of Set 8 | kurchum
# Processing Record 31 of Set 8 | nova olimpia
# Processing Record 32 of Set 8 | ushtobe
# Processing Record 33 of Set 8 | alekseyevka
# Processing Record 34 of Set 8 | marystown
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | jiayuguan
# Processing Record 37 of Set 8 | henties bay
# Processing Record 38 of Set 8 | eyl
# Processing Record 39 of Set 8 | aripuana
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | sakaraha
# Processing Record 42 of Set 8 | tessalit
# City not found. Skipping...
# Processing Record 43 of Set 8 | svetlaya
# Processing Record 44 of Set 8 | bastia
# Processing Record 45 of Set 8 | kloulklubed
# Processing Record 46 of Set 8 | palma di montechiaro
# Processing Record 47 of Set 8 | nouna
# Processing Record 48 of Set 8 | malko tarnovo
# Processing Record 49 of Set 8 | asyut
# Processing Record 50 of Set 8 | vila velha
# Processing Record 1 of Set 9 | mbanza-ngungu
# Processing Record 2 of Set 9 | ozernovskiy
# Processing Record 3 of Set 9 | luganville
# Processing Record 4 of Set 9 | clyde river
# Processing Record 5 of Set 9 | mangaluru
# Processing Record 6 of Set 9 | kaduy
# Processing Record 7 of Set 9 | bridlington
# Processing Record 8 of Set 9 | charagua
# Processing Record 9 of Set 9 | gat
# City not found. Skipping...
# Processing Record 10 of Set 9 | raja jang
# Processing Record 11 of Set 9 | tabuk
# Processing Record 12 of Set 9 | la tuque
# Processing Record 13 of Set 9 | quchan
# Processing Record 14 of Set 9 | ixtapa
# Processing Record 15 of Set 9 | taksimo
# Processing Record 16 of Set 9 | tokmak
# Processing Record 17 of Set 9 | guerrero negro
# Processing Record 18 of Set 9 | manicore
# Processing Record 19 of Set 9 | steinbach
# Processing Record 20 of Set 9 | tieli
# Processing Record 21 of Set 9 | antofagasta
# Processing Record 22 of Set 9 | sabha
# Processing Record 23 of Set 9 | mansoa
# Processing Record 24 of Set 9 | laukaa
# Processing Record 25 of Set 9 | roma
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | vestmannaeyjar
# Processing Record 28 of Set 9 | trelew
# Processing Record 29 of Set 9 | riosucio
# City not found. Skipping...
# Processing Record 30 of Set 9 | mareeba
# Processing Record 31 of Set 9 | saint-francois
# Processing Record 32 of Set 9 | warmbad
# City not found. Skipping...
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | ereymentau
# Processing Record 35 of Set 9 | columbus
# Processing Record 36 of Set 9 | armenis
# Processing Record 37 of Set 9 | porbandar
# Processing Record 38 of Set 9 | brae
# Processing Record 39 of Set 9 | greenville
# Processing Record 40 of Set 9 | robertsport
# Processing Record 41 of Set 9 | belyy
# Processing Record 42 of Set 9 | miracema do tocantins
# Processing Record 43 of Set 9 | kamina
# Processing Record 44 of Set 9 | mayumba
# Processing Record 45 of Set 9 | abu dhabi
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | pacific grove
# Processing Record 48 of Set 9 | zhuhai
# Processing Record 49 of Set 9 | puerto escondido
# Processing Record 50 of Set 9 | hami
# Processing Record 1 of Set 10 | solnechnyy
# Processing Record 2 of Set 10 | awbari
# Processing Record 3 of Set 10 | zaragoza
# Processing Record 4 of Set 10 | matara
# Processing Record 5 of Set 10 | vitim
# Processing Record 6 of Set 10 | cockburn town
# Processing Record 7 of Set 10 | mweka
# Processing Record 8 of Set 10 | isoka
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | milkovo
# City not found. Skipping...
# Processing Record 11 of Set 10 | daru
# Processing Record 12 of Set 10 | vodstroy
# Processing Record 13 of Set 10 | maridi
# Processing Record 14 of Set 10 | kuusankoski
# Processing Record 15 of Set 10 | chokurdakh
# Processing Record 16 of Set 10 | don sak
# City not found. Skipping...
# Processing Record 17 of Set 10 | ponta delgada
# Processing Record 18 of Set 10 | yantal
# Processing Record 19 of Set 10 | angatuba
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | ostrovnoy
# Processing Record 22 of Set 10 | along
# Processing Record 23 of Set 10 | muisne
# Processing Record 24 of Set 10 | ambovombe
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | sinnar
# Processing Record 27 of Set 10 | lebanon
# Processing Record 28 of Set 10 | waipawa
# Processing Record 29 of Set 10 | mandera
# Processing Record 30 of Set 10 | lujiang
# Processing Record 31 of Set 10 | homer
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | verkhnevilyuysk
# Processing Record 34 of Set 10 | jacareacanga
# Processing Record 35 of Set 10 | moscow
# Processing Record 36 of Set 10 | shelburne
# Processing Record 37 of Set 10 | seeboden
# Processing Record 38 of Set 10 | port blair
# Processing Record 39 of Set 10 | santa cruz
# Processing Record 40 of Set 10 | stephenville
# Processing Record 41 of Set 10 | hollister
# Processing Record 42 of Set 10 | springdale
# Processing Record 43 of Set 10 | gien
# Processing Record 44 of Set 10 | bouna
# Processing Record 45 of Set 10 | kyra
# Processing Record 46 of Set 10 | novellara
# Processing Record 47 of Set 10 | george town
# Processing Record 48 of Set 10 | lobito
# Processing Record 49 of Set 10 | cidreira
# Processing Record 50 of Set 10 | tarko-sale
# Processing Record 1 of Set 11 | olga
# Processing Record 2 of Set 11 | richmond hill
# Processing Record 3 of Set 11 | esik
# Processing Record 4 of Set 11 | vostok
# Processing Record 5 of Set 11 | sakakah
# City not found. Skipping...
# Processing Record 6 of Set 11 | banjar
# City not found. Skipping...
# Processing Record 7 of Set 11 | adrar
# Processing Record 8 of Set 11 | moron
# Processing Record 9 of Set 11 | ahipara
# Processing Record 10 of Set 11 | ardakan
# Processing Record 11 of Set 11 | gibara
# Processing Record 12 of Set 11 | cabedelo
# Processing Record 13 of Set 11 | yayva
# Processing Record 14 of Set 11 | ha tinh
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | vilhena
# Processing Record 17 of Set 11 | tezu
# City not found. Skipping...
# Processing Record 18 of Set 11 | ocampo
# Processing Record 19 of Set 11 | boralday
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | codrington
# Processing Record 22 of Set 11 | kuala terengganu
# Processing Record 23 of Set 11 | lagoa
# Processing Record 24 of Set 11 | lebu
# Processing Record 25 of Set 11 | orzhytsya
# Processing Record 26 of Set 11 | olpad
# Processing Record 27 of Set 11 | port lincoln
# Processing Record 28 of Set 11 | cayenne
# Processing Record 29 of Set 11 | kitgum
# Processing Record 30 of Set 11 | havelock
# Processing Record 31 of Set 11 | seoni malwa
# Processing Record 32 of Set 11 | sao domingos do prata
# Processing Record 33 of Set 11 | tougue
# Processing Record 34 of Set 11 | bentiu
# Processing Record 35 of Set 11 | oytal
# City not found. Skipping...
# Processing Record 36 of Set 11 | odesskoye
# Processing Record 37 of Set 11 | nome
# Processing Record 38 of Set 11 | misratah
# Processing Record 39 of Set 11 | natal
# Processing Record 40 of Set 11 | road town
# Processing Record 41 of Set 11 | kiunga
# Processing Record 42 of Set 11 | wamba
# Processing Record 43 of Set 11 | nadym
# Processing Record 44 of Set 11 | rantepao
# Processing Record 45 of Set 11 | zaozerne
# Processing Record 46 of Set 11 | erdaojiang
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | kitami
# Processing Record 49 of Set 11 | quang ngai
# Processing Record 50 of Set 11 | naantali
# Processing Record 1 of Set 12 | nador
# Processing Record 2 of Set 12 | tsabong
# City not found. Skipping...
# City not found. Skipping...
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# create dataframe out of cities found
cities_df = pd.DataFrame({"City": cities_found,
                          "Cloudiness": clouds,
                          "Country": countries,
                          "Date": dates,
                          "Humidity": humid,
                          "Lat": latit,
                          "Lng": lngit,
                          "Max Temp": temps,
                          "Wind Speed": wind})

# show value counts
cities_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# save dataframe to csv file
cities_df.to_csv("Output_data/cities.csv")

# show header
cities_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0             Bethel          90      US  1586444460       100  41.37  -73.41
# 1             Torbay          75      CA  1586444730        69  47.67  -52.73
# 2            Ushuaia          39      AR  1586444731        66 -54.80  -68.30
# 3  Altos del Rosario         100      CO  1586444732        65   8.79  -74.17
# 4              Bluff          98      NZ  1586444733        90 -46.60  168.33
#
#    Max Temp  Wind Speed
# 0     52.00        5.82
# 1     37.99       21.92
# 2     57.20        5.99
# 3     89.60        1.74
# 4     54.00        7.00

# %%
# scatter plot of max temperatures of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Max Temp"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of humidity of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Humidity"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of cloudiness of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Cloudiness"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of wind speeds of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Wind Speed"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.title("City Latitude vs Wind Speed (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot and regression line of northern hemisphere vs max temp
northern_df = cities_df.loc[(cities_df["Lat"] > 0),:]

x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Max Temp vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,0),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: -0.8633553545755815.

# %%
# scatter plot and regression line of southern hemisphere vs max temp
southern_df = cities_df.loc[(cities_df["Lat"] < 0),:]

x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Max Temp vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.7093330101566161.

# %%
# scatter plot and regression line of northern hemisphere vs humidity
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,0),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.28327799811565557.

# %%
# scatter plot and regression line of southern hemisphere vs humidity
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.14906876146716924.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(70,50),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.14607090840124745.

# %%
# scatter plot and regression line of southern hemisphere vs cloudiness
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.21432302523018693.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.20837156757424577.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,21),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: -0.25273217063265424.
