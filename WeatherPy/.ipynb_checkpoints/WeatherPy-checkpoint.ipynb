# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# empty lists to fill with api weather info
cities_found = []
clouds = []
countries = []
dates = []
humid = []
latit = []
lngit = []
temps = []
wind = []

# count records and sets
count = 1
group_set = 1


print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# for loop to list append each city's data
for city in cities:  
    # try and except missing data
    try: 
        response_json = requests.get(f"{url}&q={city}").json() 
        clouds.append(response_json["clouds"]["all"])
        countries.append(response_json["sys"]["country"])
        dates.append(response_json["dt"])
        humid.append(response_json["main"]["humidity"])
        temps.append(response_json["main"]["temp_max"])
        latit.append(response_json["coord"]["lat"])
        lngit.append(response_json["coord"]["lon"])
        wind.append(response_json["wind"]["speed"])
        city_index = response_json["name"]
        if count >= 50:
            count = 1
            group_set += 1
            cities_found.append(response_json["name"])
        else:
            cities_found.append(response_json["name"])
            count += 1
        
        print(f"Processing Record {count} of Set {group_set} | {city}")
        
        #  pause loop for second to not exceed API usage
        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
        
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 2 of Set 1 | come
# Processing Record 3 of Set 1 | ulladulla
# Processing Record 4 of Set 1 | mpika
# Processing Record 5 of Set 1 | kavaratti
# Processing Record 6 of Set 1 | saint anthony
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | deming
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | grindavik
# City not found. Skipping...
# Processing Record 14 of Set 1 | la ronge
# Processing Record 15 of Set 1 | vardo
# Processing Record 16 of Set 1 | nadvoitsy
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | stavern
# Processing Record 20 of Set 1 | baykit
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | fort nelson
# Processing Record 26 of Set 1 | ambulu
# City not found. Skipping...
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | zorritos
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | saint-augustin
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | gigmoto
# Processing Record 38 of Set 1 | uruzgan
# Processing Record 39 of Set 1 | prince rupert
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | quelimane
# Processing Record 42 of Set 1 | cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 1 | waitakere
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | derzhavinsk
# Processing Record 49 of Set 1 | touros
# Processing Record 50 of Set 1 | sayat
# City not found. Skipping...
# Processing Record 1 of Set 2 | takoradi
# Processing Record 2 of Set 2 | mezen
# Processing Record 3 of Set 2 | staryy oskol
# Processing Record 4 of Set 2 | gweta
# Processing Record 5 of Set 2 | ecublens
# Processing Record 6 of Set 2 | susehri
# Processing Record 7 of Set 2 | camp verde
# Processing Record 8 of Set 2 | porto empedocle
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | bilibino
# Processing Record 11 of Set 2 | turukhansk
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | ryazhsk
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | ewa beach
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | nagorsk
# Processing Record 23 of Set 2 | wonthaggi
# City not found. Skipping...
# Processing Record 24 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 25 of Set 2 | joao camara
# Processing Record 26 of Set 2 | progreso
# Processing Record 27 of Set 2 | presidencia roque saenz pena
# Processing Record 28 of Set 2 | ivanava
# Processing Record 29 of Set 2 | dalby
# Processing Record 30 of Set 2 | cairns
# Processing Record 31 of Set 2 | rio gallegos
# Processing Record 32 of Set 2 | rockport
# Processing Record 33 of Set 2 | seoul
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | aborlan
# Processing Record 36 of Set 2 | carbonia
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | coahuayana
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | oxbow
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | ostersund
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | balkhash
# Processing Record 2 of Set 3 | juruti
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | socorro
# Processing Record 5 of Set 3 | te anau
# Processing Record 6 of Set 3 | carballo
# Processing Record 7 of Set 3 | bandar-e lengeh
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | grand gaube
# Processing Record 12 of Set 3 | cam ranh
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | nalut
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | alpena
# Processing Record 17 of Set 3 | malim
# Processing Record 18 of Set 3 | igatpuri
# Processing Record 19 of Set 3 | port moresby
# Processing Record 20 of Set 3 | stornoway
# Processing Record 21 of Set 3 | kodinsk
# Processing Record 22 of Set 3 | izhma
# Processing Record 23 of Set 3 | bontang
# Processing Record 24 of Set 3 | bubaque
# Processing Record 25 of Set 3 | katunino
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | angoche
# Processing Record 30 of Set 3 | kamenka
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | manokwari
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | melton
# Processing Record 36 of Set 3 | mora
# Processing Record 37 of Set 3 | puerto del rosario
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | westport
# Processing Record 40 of Set 3 | shingu
# Processing Record 41 of Set 3 | puerto colombia
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | samarai
# Processing Record 44 of Set 3 | pedernales
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | olinala
# Processing Record 47 of Set 3 | wanaka
# Processing Record 48 of Set 3 | lasa
# Processing Record 49 of Set 3 | mitu
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | rock sound
# City not found. Skipping...
# Processing Record 2 of Set 4 | inirida
# Processing Record 3 of Set 4 | waitati
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | innisfail
# City not found. Skipping...
# Processing Record 6 of Set 4 | peleduy
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | puerto escondido
# City not found. Skipping...
# Processing Record 13 of Set 4 | coracora
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | lazaro cardenas
# Processing Record 16 of Set 4 | ixtapa
# Processing Record 17 of Set 4 | raska
# City not found. Skipping...
# Processing Record 18 of Set 4 | kloulklubed
# Processing Record 19 of Set 4 | bandarbeyla
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | college
# Processing Record 22 of Set 4 | nishihara
# Processing Record 23 of Set 4 | naze
# Processing Record 24 of Set 4 | saldanha
# Processing Record 25 of Set 4 | barranca
# Processing Record 26 of Set 4 | sambava
# Processing Record 27 of Set 4 | los andes
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | shelburne
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | atambua
# Processing Record 33 of Set 4 | oskarshamn
# City not found. Skipping...
# Processing Record 34 of Set 4 | praia da vitoria
# Processing Record 35 of Set 4 | kamina
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | umm lajj
# Processing Record 38 of Set 4 | burnie
# Processing Record 39 of Set 4 | iskateley
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | abancay
# Processing Record 42 of Set 4 | coihueco
# Processing Record 43 of Set 4 | pudozh
# Processing Record 44 of Set 4 | nara
# Processing Record 45 of Set 4 | ibra
# Processing Record 46 of Set 4 | port keats
# Processing Record 47 of Set 4 | choma
# Processing Record 48 of Set 4 | mayo
# City not found. Skipping...
# Processing Record 49 of Set 4 | altamira
# Processing Record 50 of Set 4 | krasnoselkup
# Processing Record 1 of Set 5 | petropavlovka
# Processing Record 2 of Set 5 | qianan
# Processing Record 3 of Set 5 | dikson
# Processing Record 4 of Set 5 | amapa
# Processing Record 5 of Set 5 | hanstholm
# Processing Record 6 of Set 5 | marsa matruh
# Processing Record 7 of Set 5 | arrifes
# Processing Record 8 of Set 5 | nisia floresta
# Processing Record 9 of Set 5 | kitui
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | taloqan
# City not found. Skipping...
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | norman wells
# City not found. Skipping...
# Processing Record 16 of Set 5 | ryotsu
# Processing Record 17 of Set 5 | nuuk
# City not found. Skipping...
# Processing Record 18 of Set 5 | mizdah
# Processing Record 19 of Set 5 | umri
# Processing Record 20 of Set 5 | teya
# Processing Record 21 of Set 5 | turan
# Processing Record 22 of Set 5 | kant
# Processing Record 23 of Set 5 | imeni zhelyabova
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | gagarin
# Processing Record 26 of Set 5 | namatanai
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | alamogordo
# Processing Record 29 of Set 5 | coolum beach
# Processing Record 30 of Set 5 | slave lake
# Processing Record 31 of Set 5 | petukhovo
# City not found. Skipping...
# Processing Record 32 of Set 5 | sidi ali
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | port shepstone
# Processing Record 36 of Set 5 | merida
# City not found. Skipping...
# Processing Record 37 of Set 5 | orocue
# Processing Record 38 of Set 5 | clarence town
# City not found. Skipping...
# Processing Record 39 of Set 5 | necochea
# City not found. Skipping...
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | akyab
# City not found. Skipping...
# Processing Record 42 of Set 5 | hit
# Processing Record 43 of Set 5 | bandundu
# Processing Record 44 of Set 5 | huntley
# Processing Record 45 of Set 5 | zyryanovsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | ratnagiri
# Processing Record 47 of Set 5 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 48 of Set 5 | aykhal
# Processing Record 49 of Set 5 | leh
# Processing Record 50 of Set 5 | port-gentil
# Processing Record 1 of Set 6 | nipawin
# Processing Record 2 of Set 6 | dekar
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | constitucion
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | biloela
# Processing Record 7 of Set 6 | bud
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | nouadhibou
# Processing Record 10 of Set 6 | puqi
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | abu kamal
# Processing Record 14 of Set 6 | utiel
# Processing Record 15 of Set 6 | roma
# Processing Record 16 of Set 6 | nanyamba
# Processing Record 17 of Set 6 | dutse
# Processing Record 18 of Set 6 | mushie
# Processing Record 19 of Set 6 | kalmunai
# Processing Record 20 of Set 6 | maumere
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | honiara
# Processing Record 23 of Set 6 | verkhnevilyuysk
# Processing Record 24 of Set 6 | itarema
# Processing Record 25 of Set 6 | katangli
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | bambous virieux
# Processing Record 28 of Set 6 | griffith
# Processing Record 29 of Set 6 | plainview
# Processing Record 30 of Set 6 | kazerun
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | port blair
# Processing Record 33 of Set 6 | turayf
# Processing Record 34 of Set 6 | tobane
# Processing Record 35 of Set 6 | camana
# Processing Record 36 of Set 6 | mar del plata
# Processing Record 37 of Set 6 | maldonado
# Processing Record 38 of Set 6 | lexington
# Processing Record 39 of Set 6 | safranbolu
# City not found. Skipping...
# Processing Record 40 of Set 6 | vila do maio
# Processing Record 41 of Set 6 | santiago del estero
# City not found. Skipping...
# Processing Record 42 of Set 6 | breves
# Processing Record 43 of Set 6 | orlik
# Processing Record 44 of Set 6 | taos
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | poum
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | ribeira grande
# Processing Record 49 of Set 6 | benghazi
# Processing Record 50 of Set 6 | shiraz
# Processing Record 1 of Set 7 | ungaran
# City not found. Skipping...
# Processing Record 2 of Set 7 | perth
# Processing Record 3 of Set 7 | sao paulo de olivenca
# Processing Record 4 of Set 7 | alyangula
# Processing Record 5 of Set 7 | albertville
# Processing Record 6 of Set 7 | san luis
# Processing Record 7 of Set 7 | whitianga
# Processing Record 8 of Set 7 | kropotkin
# Processing Record 9 of Set 7 | birkenfeld
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | tual
# Processing Record 12 of Set 7 | virginia beach
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | abu dhabi
# Processing Record 15 of Set 7 | huilong
# Processing Record 16 of Set 7 | surt
# Processing Record 17 of Set 7 | kungurtug
# Processing Record 18 of Set 7 | abu samrah
# Processing Record 19 of Set 7 | kosh-agach
# Processing Record 20 of Set 7 | taoudenni
# Processing Record 21 of Set 7 | komsomolets
# City not found. Skipping...
# Processing Record 22 of Set 7 | dargaville
# Processing Record 23 of Set 7 | severo-kurilsk
# Processing Record 24 of Set 7 | maceio
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | ornskoldsvik
# Processing Record 27 of Set 7 | kabare
# Processing Record 28 of Set 7 | northam
# Processing Record 29 of Set 7 | omsukchan
# Processing Record 30 of Set 7 | bengkulu
# Processing Record 31 of Set 7 | havoysund
# Processing Record 32 of Set 7 | vossevangen
# Processing Record 33 of Set 7 | adrar
# Processing Record 34 of Set 7 | clarksburg
# Processing Record 35 of Set 7 | sharjah
# Processing Record 36 of Set 7 | hienghene
# Processing Record 37 of Set 7 | resplendor
# City not found. Skipping...
# Processing Record 38 of Set 7 | clyde river
# Processing Record 39 of Set 7 | ust-kuyga
# Processing Record 40 of Set 7 | dongzhen
# Processing Record 41 of Set 7 | labuhan
# Processing Record 42 of Set 7 | isla vista
# Processing Record 43 of Set 7 | tiksi
# Processing Record 44 of Set 7 | vila velha
# City not found. Skipping...
# Processing Record 45 of Set 7 | ola
# Processing Record 46 of Set 7 | sarkand
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | sept-iles
# Processing Record 49 of Set 7 | pinheiro machado
# Processing Record 50 of Set 7 | meulaboh
# Processing Record 1 of Set 8 | aras
# Processing Record 2 of Set 8 | manuk mangkaw
# Processing Record 3 of Set 8 | sobolevo
# Processing Record 4 of Set 8 | wenling
# Processing Record 5 of Set 8 | karratha
# Processing Record 6 of Set 8 | pundaguitan
# Processing Record 7 of Set 8 | orange cove
# Processing Record 8 of Set 8 | slavgorodskoye
# Processing Record 9 of Set 8 | saint george
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | portknockie
# Processing Record 12 of Set 8 | bridlington
# City not found. Skipping...
# Processing Record 13 of Set 8 | coihaique
# Processing Record 14 of Set 8 | egvekinot
# Processing Record 15 of Set 8 | rantauprapat
# Processing Record 16 of Set 8 | kutum
# City not found. Skipping...
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | donskoye
# Processing Record 19 of Set 8 | alice springs
# Processing Record 20 of Set 8 | razdolinsk
# Processing Record 21 of Set 8 | sangueya
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | quimper
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | palkino
# Processing Record 27 of Set 8 | korla
# Processing Record 28 of Set 8 | guerrero negro
# Processing Record 29 of Set 8 | oktyabrskoye
# Processing Record 30 of Set 8 | halifax
# Processing Record 31 of Set 8 | harrisonburg
# Processing Record 32 of Set 8 | catalao
# City not found. Skipping...
# Processing Record 33 of Set 8 | nanakuli
# Processing Record 34 of Set 8 | tskaltubo
# Processing Record 35 of Set 8 | cavalcante
# Processing Record 36 of Set 8 | yar-sale
# Processing Record 37 of Set 8 | sulangan
# Processing Record 38 of Set 8 | lodja
# Processing Record 39 of Set 8 | mount isa
# Processing Record 40 of Set 8 | kangaatsiaq
# Processing Record 41 of Set 8 | koka
# Processing Record 42 of Set 8 | kindu
# Processing Record 43 of Set 8 | moussoro
# City not found. Skipping...
# Processing Record 44 of Set 8 | quatre cocos
# Processing Record 45 of Set 8 | uni
# Processing Record 46 of Set 8 | iaciara
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | kaitangata
# Processing Record 49 of Set 8 | narsaq
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | rawatsar
# City not found. Skipping...
# Processing Record 2 of Set 9 | mwense
# Processing Record 3 of Set 9 | kupang
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | unity
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | kotka
# City not found. Skipping...
# Processing Record 8 of Set 9 | tilichiki
# Processing Record 9 of Set 9 | wachtberg
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | huarmey
# Processing Record 12 of Set 9 | tuatapere
# Processing Record 13 of Set 9 | mount pleasant
# Processing Record 14 of Set 9 | bakchar
# Processing Record 15 of Set 9 | padang
# Processing Record 16 of Set 9 | christchurch
# Processing Record 17 of Set 9 | catanzaro
# Processing Record 18 of Set 9 | bathsheba
# Processing Record 19 of Set 9 | filadelfia
# Processing Record 20 of Set 9 | fayaoue
# Processing Record 21 of Set 9 | buta
# Processing Record 22 of Set 9 | aksay
# Processing Record 23 of Set 9 | saint-francois
# Processing Record 24 of Set 9 | sioux lookout
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | dickinson
# Processing Record 27 of Set 9 | torbay
# Processing Record 28 of Set 9 | marawi
# Processing Record 29 of Set 9 | caibarien
# City not found. Skipping...
# Processing Record 30 of Set 9 | lysva
# Processing Record 31 of Set 9 | mayumba
# Processing Record 32 of Set 9 | vanimo
# Processing Record 33 of Set 9 | lufilufi
# Processing Record 34 of Set 9 | pasighat
# City not found. Skipping...
# Processing Record 35 of Set 9 | cooma
# Processing Record 36 of Set 9 | lorengau
# City not found. Skipping...
# Processing Record 37 of Set 9 | marzuq
# Processing Record 38 of Set 9 | nuevo progreso
# Processing Record 39 of Set 9 | roald
# City not found. Skipping...
# Processing Record 40 of Set 9 | kuningan
# Processing Record 41 of Set 9 | pilar
# Processing Record 42 of Set 9 | puerto madryn
# Processing Record 43 of Set 9 | krzeszowice
# Processing Record 44 of Set 9 | heihe
# Processing Record 45 of Set 9 | fillan
# Processing Record 46 of Set 9 | qaqortoq
# Processing Record 47 of Set 9 | elblag
# Processing Record 48 of Set 9 | ghatampur
# City not found. Skipping...
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | mirnyy
# Processing Record 2 of Set 10 | flin flon
# Processing Record 3 of Set 10 | mattru
# Processing Record 4 of Set 10 | lachhmangarh
# Processing Record 5 of Set 10 | tumut
# Processing Record 6 of Set 10 | williams lake
# Processing Record 7 of Set 10 | chara
# Processing Record 8 of Set 10 | severobaykalsk
# Processing Record 9 of Set 10 | humaita
# Processing Record 10 of Set 10 | phek
# Processing Record 11 of Set 10 | charyshskoye
# Processing Record 12 of Set 10 | cumra
# Processing Record 13 of Set 10 | mabaruma
# Processing Record 14 of Set 10 | talara
# Processing Record 15 of Set 10 | canutama
# Processing Record 16 of Set 10 | moindou
# Processing Record 17 of Set 10 | kaili
# Processing Record 18 of Set 10 | solnechnyy
# Processing Record 19 of Set 10 | nampula
# Processing Record 20 of Set 10 | karpathos
# Processing Record 21 of Set 10 | koumac
# Processing Record 22 of Set 10 | walvis bay
# Processing Record 23 of Set 10 | drayton valley
# Processing Record 24 of Set 10 | ballina
# Processing Record 25 of Set 10 | cabo san lucas
# Processing Record 26 of Set 10 | maarianhamina
# Processing Record 27 of Set 10 | kuito
# Processing Record 28 of Set 10 | broken hill
# Processing Record 29 of Set 10 | bonthe
# City not found. Skipping...
# Processing Record 30 of Set 10 | manta
# Processing Record 31 of Set 10 | mana
# Processing Record 32 of Set 10 | contamana
# Processing Record 33 of Set 10 | oriximina
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | meulebeke
# Processing Record 36 of Set 10 | pochutla
# Processing Record 37 of Set 10 | aksu
# Processing Record 38 of Set 10 | kawalu
# Processing Record 39 of Set 10 | zhuhai
# City not found. Skipping...
# Processing Record 40 of Set 10 | camopi
# Processing Record 41 of Set 10 | nancha
# Processing Record 42 of Set 10 | caceres
# Processing Record 43 of Set 10 | yumen
# Processing Record 44 of Set 10 | sungairaya
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | cap malheureux
# Processing Record 47 of Set 10 | winnemucca
# Processing Record 48 of Set 10 | nongan
# Processing Record 49 of Set 10 | wilmington
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | vestmannaeyjar
# Processing Record 2 of Set 11 | rawson
# Processing Record 3 of Set 11 | asyut
# Processing Record 4 of Set 11 | boshnyakovo
# Processing Record 5 of Set 11 | kearney
# Processing Record 6 of Set 11 | guanambi
# Processing Record 7 of Set 11 | saint-joseph
# Processing Record 8 of Set 11 | lerida
# Processing Record 9 of Set 11 | marysville
# Processing Record 10 of Set 11 | launceston
# Processing Record 11 of Set 11 | buraydah
# Processing Record 12 of Set 11 | betania
# Processing Record 13 of Set 11 | msowero
# Processing Record 14 of Set 11 | darnah
# Processing Record 15 of Set 11 | archidona
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | fukuma
# Processing Record 18 of Set 11 | esmeraldas
# Processing Record 19 of Set 11 | luebo
# City not found. Skipping...
# Processing Record 20 of Set 11 | morro bay
# Processing Record 21 of Set 11 | miranda
# City not found. Skipping...
# Processing Record 22 of Set 11 | la orilla
# Processing Record 23 of Set 11 | dingli
# Processing Record 24 of Set 11 | aleksandrovskoye
# Processing Record 25 of Set 11 | zemio
# Processing Record 26 of Set 11 | san policarpo
# Processing Record 27 of Set 11 | faxinal
# Processing Record 28 of Set 11 | sarakhs
# Processing Record 29 of Set 11 | manggar
# Processing Record 30 of Set 11 | yarqa
# Processing Record 31 of Set 11 | two hills
# Processing Record 32 of Set 11 | port lincoln
# Processing Record 33 of Set 11 | fort saint james
# Processing Record 34 of Set 11 | wagar
# Processing Record 35 of Set 11 | anadyr
# Processing Record 36 of Set 11 | lethem
# Processing Record 37 of Set 11 | maracaibo
# Processing Record 38 of Set 11 | belin
# Processing Record 39 of Set 11 | platanos
# Processing Record 40 of Set 11 | codrington
# Processing Record 41 of Set 11 | tucuma
# Processing Record 42 of Set 11 | la ferte-bernard
# Processing Record 43 of Set 11 | ban nahin
# Processing Record 44 of Set 11 | shenjiamen
# Processing Record 45 of Set 11 | mount vernon
# Processing Record 46 of Set 11 | nuristan
# Processing Record 47 of Set 11 | along
# Processing Record 48 of Set 11 | neiafu
# Processing Record 49 of Set 11 | plettenberg bay
# Processing Record 50 of Set 11 | acari
# Processing Record 1 of Set 12 | kayerkan
# Processing Record 2 of Set 12 | gravdal
# Processing Record 3 of Set 12 | ndende
# Processing Record 4 of Set 12 | japura
# Processing Record 5 of Set 12 | tuy hoa
# Processing Record 6 of Set 12 | yinchuan
# Processing Record 7 of Set 12 | pontes e lacerda
# Processing Record 8 of Set 12 | alofi
# Processing Record 9 of Set 12 | manicore
# Processing Record 10 of Set 12 | balingasay
# Processing Record 11 of Set 12 | sumbe
# Processing Record 12 of Set 12 | susanville
# Processing Record 13 of Set 12 | cassilandia
# Processing Record 14 of Set 12 | balao
# Processing Record 15 of Set 12 | tiarei
# Processing Record 16 of Set 12 | praia
# Processing Record 17 of Set 12 | sao joao da barra
# Processing Record 18 of Set 12 | mehamn
# Processing Record 19 of Set 12 | lieksa
# Processing Record 20 of Set 12 | cosala
# Processing Record 21 of Set 12 | berlevag
# Processing Record 22 of Set 12 | sechura
# Processing Record 23 of Set 12 | pombas
# City not found. Skipping...
# Processing Record 24 of Set 12 | kununurra
# Processing Record 25 of Set 12 | beipiao
# Processing Record 26 of Set 12 | aksha
# Processing Record 27 of Set 12 | reinosa
# Processing Record 28 of Set 12 | galle
# Processing Record 29 of Set 12 | corinto
# Processing Record 30 of Set 12 | den helder
# Processing Record 31 of Set 12 | sakaraha
# Processing Record 32 of Set 12 | tessalit
# City not found. Skipping...
# Processing Record 33 of Set 12 | sistranda
# Processing Record 34 of Set 12 | ambon
# Processing Record 35 of Set 12 | thayetmyo
# Processing Record 36 of Set 12 | pangnirtung
# Processing Record 37 of Set 12 | port-cartier
# Processing Record 38 of Set 12 | mali
# Processing Record 39 of Set 12 | vynohradove
# Processing Record 40 of Set 12 | lamu
# Processing Record 41 of Set 12 | ramsar
# Processing Record 42 of Set 12 | kailua
# Processing Record 43 of Set 12 | kuusamo
# Processing Record 44 of Set 12 | edd
# Processing Record 45 of Set 12 | ilhabela
# Processing Record 46 of Set 12 | massaguet
# Processing Record 47 of Set 12 | dongsheng
# Processing Record 48 of Set 12 | warrnambool
# Processing Record 49 of Set 12 | sumkino
# Processing Record 50 of Set 12 | narok
# Processing Record 1 of Set 13 | ancud
# Processing Record 2 of Set 13 | pareora
# Processing Record 3 of Set 13 | axim
# Processing Record 4 of Set 13 | antonovo
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# create dataframe out of cities found
cities_df = pd.DataFrame({"City": cities_found,
                          "Cloudiness": clouds,
                          "Country": countries,
                          "Date": dates,
                          "Humidity": humid,
                          "Lat": latit,
                          "Lng": lngit,
                          "Max Temp": temps,
                          "Wind Speed": wind})

# show value counts
cities_df.count()
# Out:
# City          603
# Cloudiness    603
# Country       603
# Date          603
# Humidity      603
# Lat           603
# Lng           603
# Max Temp      603
# Wind Speed    603
# dtype: int64

# %%
# save dataframe to csv file
cities_df.to_csv("../Output_data/cities.csv")

# show header
cities_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Comé          40      BJ  1586651214        79   6.41    1.88
# 1      Ulladulla           0      AU  1586651215        39 -35.35  150.47
# 2          Mpika          81      ZM  1586651216        63 -11.83   31.45
# 3      Kavaratti           4      IN  1586651080        69  10.57   72.64
# 4  Saint Anthony          90      US  1586651218        26  45.02  -93.22
#
#    Max Temp  Wind Speed
# 0     84.20        5.82
# 1     64.40       12.75
# 2     62.24        8.32
# 3     84.04        4.61
# 4     59.00        9.17

# %%
# scatter plot of max temperatures of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Max Temp"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of humidity of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Humidity"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of cloudiness of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Cloudiness"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot of wind speeds of city latitudes
x_values = cities_df["Lat"]
y_values = cities_df["Wind Speed"]

plt.scatter(x_values, y_values, marker = "o", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.title("City Latitude vs Wind Speed (4/8/2020)")
plt.grid(color = "grey",)

# %%
# scatter plot and regression line of northern hemisphere vs max temp
northern_df = cities_df.loc[(cities_df["Lat"] > 0),:]

x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Max Temp vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,0),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: -0.9064291929236817.

# %%
# scatter plot and regression line of southern hemisphere vs max temp
southern_df = cities_df.loc[(cities_df["Lat"] < 0),:]

x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Max Temp vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6781965256666485.

# %%
# scatter plot and regression line of northern hemisphere vs humidity
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,10),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.21799466031260592.

# %%
# scatter plot and regression line of southern hemisphere vs humidity
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-10,20),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.35240706567309527.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(70,50),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.13959483325176592.

# %%
# scatter plot and regression line of southern hemisphere vs cloudiness
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.1616945301863087.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Northern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.15265690380319624.

# %%
# scatter plot and regression line of northern hemisphere vs cloudiness
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Southern Hemisphere Latitudes")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,21),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: -0.43897604481149133.
